# %%
import os
import pickle
import numpy as np
import torch

path = "/cluster/project/krause/frankem/chemflow/data/geom/raw/test_data.pickle"

with open(path, "rb") as f:
    data = pickle.load(f)

# %%
len(data)
# Out:
# 30434

# %%
data[0]
# Out:
# ('Brc1c(CSc2nc3ccccc3s2)nc2ncccn12',
# ...
#   <rdkit.Chem.rdchem.Mol at 0x14d4cf4ccd10>])
